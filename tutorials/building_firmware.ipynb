# %% [markdown]
# # Building Firmware for the Acadia Control System
#
# A major benefit of the Acadia architecture is its ability to be easily reconfigured with firmware images defined in Python, rather than in pure VHDL. This guide will walk through the build process for a Python-defined image and explain the various utilities provided for doing so.
#
# First, we'll import the necessary libraries. The firmware we want to build is written as a class that we can directly import:

# %%
from acadia.hardware.firmware.standard_firmware import StandardFirmware
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_2418949/3101160396.py in <module>
# ----> 1 from acadia.hardware.firmware.standard_firmware import StandardFirmware
#
# ~/acadia/pyacadia/acadia/hardware/firmware/standard_firmware.py in <module>
# ----> 1 from .firmware_utils import *
#       2 import os
#       3
#       4 class StandardFirmware(Firmware):
#       5     # Designate some addresses for memory slave segments
#
# ModuleNotFoundError: No module named 'acadia.hardware.firmware.firmware_utils'

# %%
from acadia import
